# %% [markdown]
# **FUNDAMENTAL OF COST FUNCTION FOR LINEAR REGRESSION MODEL**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])  #(m,n)
y_train = np.array([0, 0, 0, 1, 1, 1])                                           #(m,)

# %% [markdown]
# **Classifying the categories**

# %%
pos = y_train==1
neg = y_train == 0
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# **Plotting the diagram**

# %%
plt.figure(figsize = (12,4))
plt.scatter(X_train[pos,0],X_train[pos,1],marker='o',c='b',label='Positive')  #this is our positive class
plt.scatter(X_train[neg,0],X_train[neg,1],marker='x',c='r',label='Negative') #this is our negative class
plt.legend()
plt.show()
